# %% [markdown]
# 1. Importing the Libraries

# %%
import pandas as pd

# %% [markdown]
# 2. Importing the Dataset

# %%
data = pd.read_csv(r"C:\Users\Lenovo\Downloads\heart.csv")

# %% [markdown]
# 3. Taking Care of Missing Values

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# 4. Taking Care of Duplicate Values

# %%
data_dup = data.duplicated().any()

# %%
data_dup
# Out:
# np.True_

# %%
data = data.drop_duplicates()

# %%
data_dup = data.duplicated().any()

# %%
data_dup
# Out:
# np.False_

# %% [markdown]
# 5. Data Processing

# %%
cate_val=[]
cont_val=[]

for column in data.columns:
    if data[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %% [markdown]
# 6. Encoding Categorical Data

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
data['cp'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
cate_val.remove('sex')
cate_val.remove('target')
data=pd.get_dummies(data,columns=cate_val,drop_first=True)

# %%
data.head()
# Out:
#    age  sex  trestbps  chol  thalach  oldpeak  target   cp_1   cp_2   cp_3  \
# 0   52    1       125   212      168      1.0       0  False  False  False
# 1   53    1       140   203      155      3.1       0  False  False  False
# 2   70    1       145   174      125      2.6       0  False  False  False
# 3   61    1       148   203      161      0.0       0  False  False  False
# 4   62    0       138   294      106      1.9       0  False  False  False
#
#    ...  exang_1  slope_1  slope_2   ca_1   ca_2   ca_3   ca_4  thal_1  thal_2  \
# 0  ...    False    False     True  False   True  False  False   False   False
# 1  ...     True    False    False  False  False  False  False   False   False
# 2  ...     True    False    False  False  False  False  False   False   False
# 3  ...    False    False     True   True  False  False  False   False   False
# 4  ...    False     True    False  False  False   True  False   False    True
#
#    thal_3
# 0    True
# 1    True
# 2    True
# ...

# %% [markdown]
# 7. Feature Scaling

# %%
data.head()
# Out:
#    age  sex  trestbps  chol  thalach  oldpeak  target   cp_1   cp_2   cp_3  \
# 0   52    1       125   212      168      1.0       0  False  False  False
# 1   53    1       140   203      155      3.1       0  False  False  False
# 2   70    1       145   174      125      2.6       0  False  False  False
# 3   61    1       148   203      161      0.0       0  False  False  False
# 4   62    0       138   294      106      1.9       0  False  False  False
#
#    ...  exang_1  slope_1  slope_2   ca_1   ca_2   ca_3   ca_4  thal_1  thal_2  \
# 0  ...    False    False     True  False   True  False  False   False   False
# 1  ...     True    False    False  False  False  False  False   False   False
# 2  ...     True    False    False  False  False  False  False   False   False
# 3  ...    False    False     True   True  False  False  False   False   False
# 4  ...    False     True    False  False  False   True  False   False    True
#
#    thal_3
# 0    True
# 1    True
# 2    True
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
st = StandardScaler()
data[cont_val] = st.fit_transform(data[cont_val])

# %%
data.head()
# Out:
#         age  sex  trestbps      chol   thalach   oldpeak  target   cp_1  \
# 0 -0.267966    1 -0.376556 -0.667728  0.806035 -0.037124       0  False
# 1 -0.157260    1  0.478910 -0.841918  0.237495  1.773958       0  False
# 2  1.724733    1  0.764066 -1.403197 -1.074521  1.342748       0  False
# 3  0.728383    1  0.935159 -0.841918  0.499898 -0.899544       0  False
# 4  0.839089    0  0.364848  0.919336 -1.905464  0.739054       0  False
#
#     cp_2   cp_3  ...  exang_1  slope_1  slope_2   ca_1   ca_2   ca_3   ca_4  \
# 0  False  False  ...    False    False     True  False   True  False  False
# 1  False  False  ...     True    False    False  False  False  False  False
# 2  False  False  ...     True    False    False  False  False  False  False
# 3  False  False  ...    False    False     True   True  False  False  False
# 4  False  False  ...    False     True    False  False  False   True  False
#
#    thal_1  thal_2  thal_3
# 0   False   False    True
# ...

# %% [markdown]
# 8. Splitting The Dataset Into The Training Set And Test Set

# %%
x = data.drop('target',axis=1)

# %%
y = data['target']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_test
# Out:
#           age  sex  trestbps      chol   thalach   oldpeak   cp_1   cp_2  \
# 245 -1.153610    1 -0.091401 -0.532247  1.680713 -0.899544   True  False
# 349  0.839089    0 -0.091401  0.319348 -2.299069  0.135360  False   True
# 135  0.396267    0  2.189843 -0.416120 -0.156110  1.515232  False  False
# 389  0.949794    1  0.764066 -0.261285  0.018826  1.084022  False  False
# 66  -0.157260    1 -0.091401 -0.958045  0.106294  0.135360  False   True
# ..        ...  ...       ...       ...       ...       ...    ...    ...
# 402  1.724733    1  1.391408 -0.029032 -0.287311 -0.899544   True  False
# 123  1.171205    0  0.478910  3.299932  0.324963 -0.209608  False   True
# 739 -0.267966    1 -0.205463  0.164513  0.499898 -0.899544  False  False
# 274  1.281911    1  1.619532 -0.358057 -0.505981  1.084022  False  False
# 256 -2.149959    0  0.364848 -1.229007  1.418309  0.307844  False  False
#
#       cp_3  fbs_1  ...  exang_1  slope_1  slope_2   ca_1   ca_2   ca_3   ca_4  \
# ...

# %%
y_test
# Out:
# 245    1
# 349    0
# 135    0
# 389    1
# 66     1
#       ..
# 402    1
# 123    1
# 739    0
# 274    1
# 256    1
# Name: target, Length: 61, dtype: int64

# %% [markdown]
# 9. Logistic Regression

# %%
data.head()
# Out:
#         age  sex  trestbps      chol   thalach   oldpeak  target   cp_1  \
# 0 -0.267966    1 -0.376556 -0.667728  0.806035 -0.037124       0  False
# 1 -0.157260    1  0.478910 -0.841918  0.237495  1.773958       0  False
# 2  1.724733    1  0.764066 -1.403197 -1.074521  1.342748       0  False
# 3  0.728383    1  0.935159 -0.841918  0.499898 -0.899544       0  False
# 4  0.839089    0  0.364848  0.919336 -1.905464  0.739054       0  False
#
#     cp_2   cp_3  ...  exang_1  slope_1  slope_2   ca_1   ca_2   ca_3   ca_4  \
# 0  False  False  ...    False    False     True  False   True  False  False
# 1  False  False  ...     True    False    False  False  False  False  False
# 2  False  False  ...     True    False    False  False  False  False  False
# 3  False  False  ...    False    False     True   True  False  False  False
# 4  False  False  ...    False     True    False  False  False   True  False
#
#    thal_1  thal_2  thal_3
# 0   False   False    True
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.7868852459016393

# %% [markdown]
# 10. SCV (Support Vector Classifier)

# %%
from sklearn import svm

# %%
svm = svm.SVC()

# %%
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred2 = svm.predict(x_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.8032786885245902

# %% [markdown]
# 11. KNeighbors Classifier

# %%
from sklearn .neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3 = knn.predict(x_test)

# %%
accuracy_score(y_test, y_pred3)
# Out:
# 0.7377049180327869

# %%
score = []

for k in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    score.append (accuracy_score(y_test, y_pred))

# %%
score
# Out:
# [0.7213114754098361,
#  0.8032786885245902,
#  0.7049180327868853,
#  0.7049180327868853,
#  0.7377049180327869,
#  0.8032786885245902,
#  0.7868852459016393,
#  0.8032786885245902,
#  0.7704918032786885,
#  0.7540983606557377,
#  0.7704918032786885,
#  0.7540983606557377,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7540983606557377,
#  0.7704918032786885,
#  0.7540983606557377,
#  0.7540983606557377,
#  0.7377049180327869,
#  0.7540983606557377,
#  0.7377049180327869,
#  0.7213114754098361,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7213114754098361,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869,
#  0.7377049180327869]

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8032786885245902

# %% [markdown]
#  Non-Linear ML Algorithms

# %%
data = pd.read_csv(r"C:\Users\Lenovo\Downloads\heart.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %%
x = data.drop('target', axis = 1)
y = data['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# 12. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4 = dt.predict(x_test)

# %%
accuracy_score(y_test, y_pred4)
# Out:
# 0.7049180327868853

# %% [markdown]
# 13. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred5 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred5)
# Out:
# 0.8360655737704918

# %% [markdown]
# 14. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit (x_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred6 = gbc.predict(x_test)

# %%
accuracy_score(y_test, y_pred6)
# Out:
# 0.8032786885245902

# %%
final_data = pd.DataFrame({'Models' : ['LR', 'SVM', 'KNN', 'DT', 'RF', 'GBC'], 
                           'ACC' : [accuracy_score(y_test, y_pred1),
                                    accuracy_score(y_test, y_pred2),
                                    accuracy_score(y_test, y_pred3),
                                    accuracy_score(y_test, y_pred4),
                                    accuracy_score(y_test, y_pred5),
                                    accuracy_score(y_test, y_pred6)]})

# %%
final_data
# Out:
#   Models       ACC
# 0     LR  0.786885
# 1    SVM  0.803279
# 2    KNN  0.737705
# 3     DT  0.704918
# 4     RF  0.836066
# 5    GBC  0.803279

# %%
import seaborn as sns

# %%
sns.barplot(x = 'Models', y = 'ACC' , data = final_data)
# Out:
# <Axes: xlabel='Models', ylabel='ACC'>

# %%
x = data.drop('target', axis = 1)
y = data['target']

# %%
x.shape
# Out:
# (302, 13)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x, y)
# Out:
# RandomForestClassifier()

# %% [markdown]
# 15. Prediction on New Data

# %%
import pandas as pd

# %%
new_data = pd.DataFrame({
    'age' : 52,
    'sex' : 1,
    'cp' : 0,
    'trestbps' : 125,
    'chol' : 212,
    'fbs' : 0,
    'restecg' : 1,
    'thalach' : 168,
    'exang' : 0,
    'oldpeak' : 1.0,
    'slope' : 2,
    'ca' : 2,
    'thal' : 3 } , index = [0])

# %%
new_data
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
#
#    ca  thal
# 0   2     3

# %%
p = rf.predict(new_data)
if p[0] == 0:
    print("No Disease")
else:
    print("Have risk pf Heart Disease")
# Out:
# No Disease

# %% [markdown]
# 16. Save Model Using Joblib

# %%
import joblib

# %%
joblib.dump(rf, 'model_joblib_heart')
# Out:
# ['model_joblib_heart']

# %%
model = joblib.load('model_joblib_heart')

# %%
model.predict(new_data)
# Out:
# array([0])

# %% [markdown]
# GUI

# %%
from tkinter import *
import joblib

# %%
def show_entry_fields():
    p1 = int(e1.get())
    p2 = int(e2.get())
    p3 = int(e3.get())
    p4 = int(e4.get())
    p5 = int(e5.get())
    p6 = int(e6.get())
    p7 = int(e7.get())
    p8 = int(e8.get())
    p9 = int(e9.get())
    p10 = int(e10.get())
    p11= int(e11.get())
    p12= int(e12.get())
    p13= int(e13.get())
    
    model = joblib.load('model_joblib_heart')
    result = model.predict([[p1,p2,p3,p4,p5,p6,p7,p8,p9,p10,p11,p12,p13]])

    if result == 0 :
        Label(master, text="No Heart Diseases").grid(row=31)
    else :
        Label(master, text="Possibility of Heart Diseases").grid(row=31)

master = Tk()
master.title("Heart Diseases Prediction System")

label = Label ( master, text = "Heart Diseases Prediction System" ,
                            bg = "black", fg = "white").grid(row=0, columnspan = 2)

Label(master, text = " Enter Age").grid(row = 1)
Label(master, text = " Enter Male or Female [1/0]").grid(row = 1)
Label(master, text = " Enter Value of CP").grid(row = 1)
Label(master, text = " Enter Value of trestbps").grid(row = 1)
Label(master, text = " Enter Value of chol").grid(row = 1)
Label(master, text = " Enter Value of fbs").grid(row = 1)
Label(master, text = " Enter Value of restecg").grid(row = 1)
Label(master, text = " Enter Value of thalach").grid(row = 1)
Label(master, text = " Enter Value of exang").grid(row = 1)
Label(master, text = " Enter Value of oldpeak").grid(row = 1)
Label(master, text = " Enter Value of slope").grid(row = 1)
Label(master, text = " Enter Value of ca").grid(row = 1)
Label(master, text = " Enter Value of thal").grid(row = 1)

e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)
e8 = Entry(master)
e9 = Entry(master)
e10 = Entry(master)
e11= Entry(master)
e12= Entry(master)
e13= Entry(master)

e1.grid(row = 1, column = 1)
e2.grid(row = 2, column = 1)
e3.grid(row = 3, column = 1)
e4.grid(row = 4, column = 1)
e5.grid(row = 5, column = 1)
e6.grid(row = 6, column = 1)
e7.grid(row = 7, column = 1)
e8.grid(row = 8, column = 1)
e9.grid(row = 9, column = 1)
e10.grid(row = 10, column = 1)
e11.grid(row = 11, column = 1)
e12.grid(row = 12, column = 1)
e13.grid(row = 13, column = 1)


Button(master, text = 'predict', command = show_entry_fields).grid()

mainloop()
